# %%
import importlib
import src.services.split_dataset as sd
importlib.reload(sd)
# Out:
# <module 'src.services.split_dataset' from 'c:\\Users\\alren\\OneDrive - Ontario Lottery and Gaming Corporation\\Desktop\\MMAI894 Final Project\\MMAI894_Final_Project\\src\\services\\split_dataset.py'>

# %%
train_df, val_df, test_df = sd.split_dataset(
    input_csv_path="../data/processed/Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11_processed.csv",
    output_dir="../data/interim/"
)
# Out:
# Dataset split completed. Files saved to ../data/interim/

# %%
# sanity check to see splits
print(f"Train set size: {len(train_df)}")
print(f"Validation set size: {len(val_df)}")
print(f"Test set size: {len(test_df)}")
# Out:
# Train set size: 21496
# Validation set size: 2688
# Test set size: 2688

# %%
train_df.head()
# Out:
#        flags                                        instruction  category  \
# 6126     BLZ  I need help seeing in which cases can I ask fo...    REFUND
# 11723  BELQZ  i do not knwo what i have to do to remove my P...   ACCOUNT
# 12813     BK                             check delivery options  DELIVERY
# 9617     BEL  I do not know what I have to do to speak with ...   CONTACT
# 19114   BLMQ             need to purchase several of ur article     ORDER
#
#                     intent                                           response
# 6126   check_refund_policy  I'll make it happen! I understand that you wou...
# 11723       delete_account  Thank you for your message to us about removin...
# 12813     delivery_options  For sure! Let's delve into the realm of delive...
# 9617   contact_human_agent  Grateful for your contact! I get the sense tha...
# 19114          place_order  Thank you for expressing your intention to pur...

# %%
val_df.head()
# Out:
#       flags                                        instruction      category  \
# 17728    BL  I can't cancel the subscription to your corpor...  SUBSCRIPTION
# 1194    BLM  I want to change several products of order ORD...         ORDER
# 6821     BL  I want help seeing in which situations can I a...        REFUND
# 25881   BQW          I'm waiting for a damn refund of £€284.92        REFUND
# 15111  BILM  how can I download the invoices from Ethan Wil...       INVOICE
#
#                         intent  \
# 17728  newsletter_subscription
# 1194              change_order
# 6821       check_refund_policy
# 25881             track_refund
# 15111              get_invoice
#
#                                                 response
# 17728  I realized you're experiencing difficulties ca...
# 1194   First of all, thank you for your request to ch...
# 6821   Always good to connect! I'm attuned to the fac...
# 25881  I'm clearly cognizant the frustration and anti...
# ...

# %%
test_df.head()
# Out:
#        flags                                        instruction category  \
# 9329     BLZ                   I can't talk with  a human agent  CONTACT
# 4160    BLMZ   I have got to locate hte bills from Maria Garcia  INVOICE
# 18500  BCELM  I cannot pay, help me to inform of a problem w...  PAYMENT
# 8840      BL           I want help speaking to customer service  CONTACT
# 5098     BLZ           I try to see th accepted payment options  PAYMENT
#
#                          intent  \
# 9329        contact_human_agent
# 4160              check_invoice
# 18500             payment_issue
# 8840   contact_customer_service
# 5098      check_payment_methods
#
#                                                 response
# 9329   Thank you for reaching out! I'm sorry to hear ...
# 4160   I'll get right on it! I understand your need t...
# 18500  I apologize for the inconvenience caused by th...
# 8840   Grateful for your contact! I get the sense tha...
# ...
